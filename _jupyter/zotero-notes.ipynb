# %% [markdown]
# When reviewing the literature, it's nice to have the notes linked to Zotero references. It would also be great to compare them systematically. The idea would be to have your notes in Zotero so that everyone in the group can access and edit them and create a data file to explore your notes using, for instance, text analysis techniques.
#
# This small package extracts notes from a collection and creates a CSV file that can be easily read using Excel. You only need to specify the collection ID. For instance, if the location of my collection is `https://www.zotero.org/groups/2406179/csic-echo/collections/M8N2VMAP`, the collection ID would be `M8N2VMAP`. We also need the Zotero API's credentials.
#
# To create a clean CSV, notes' headers would need a suitable separator. The default is `#`. In this case, the text between headings mustn't include `#`. Below an example:
#
# ```
# # Research question
#
# Estimates interaction effects between PGS of obesity and cohorts using HRS.
#
# # Data
#
# HRS
#
# # Methods
#
# Uses a HLM whereby they estimate effects of age and cohorts while making the intercepts and slopes a function of individual factors.
# ```
#
# ## Installation
#
# ```
# pip install git+https://github.com/sdaza/zotnote.git
# ```
#
# ## Credentials
#
# You can save your Zotero API credentials in a `config.py` and load them using `import config`:
#
# ```yaml
# library_id = "0000000"
# api_key = "key"
# library_type = "group"
# ```
#
# ## Example
#
# Let's try to extract the notes and read the using Pandas:

# %%
import pandas as pd
import config
import zotnote as zn

# %%
zn.exportNotes(collection = "M8N2VMAP", 
    library_id = config.library_id, api_key = config.api_key)
# Out:
# Notes saved in zotero-notes.csv

# %%
pd.read_csv("zotero-notes.csv")
# Out:
#          id                     citation                               tags  \
# 0  4ESWAPZY         van Dijk et al. 2015                                NaN
# 1  5JNF33U8  Fernandez-Twinn et al. 2019  intrauterine effects, epigenetics
# 2  S8FZS32L                    Ling 2019                              Elena
# 3  QY3Y7V6X            Sharp et al. 2017                          Must read
# 4  5AMCHQMB             Sulc et al. 2020                                NaN
# 5  U4MNK7QT           Walter et al. 2016            Genomics, HRS, GxE, BMI
# 6  RGDC9R9R            Abadi et al. 2017            Genomics, GxG, GxE, BMI
#
#                                                title   reviewer  \
# 0  Recent developments on the role of epigenetics...      Elena
# 1  Intrauterine programming of obesity and type 2...      Elena
# 2   Epigenetics in Human Obesity and Type 2 Diabetes      Elena
# 3  Maternal BMI at the start of pregnancy and off...      Elena
# 4  Quantification of the overall contribution of ...  Sebastian
# 5  Association of a Genetic Risk Score With Body ...  Sebastian
# 6  Penetrance of Polygenic Obesity Susceptibility...  Sebastian
#
#                                    research_question  \
# 0  Knowledge about epigenetic marks related to ob...
# 1  Which are the relevant exposures related to th...
# 2  Summarizes epigenetic signatures from human ti...
# 3  Is maternal bmi related with changes in the of...
# 4  Can we use a method to estimate GxE without me...
# 5  Estimates interaction effects between PGS of o...
# 6  Are the effects of obesity-susceptibility loci...
#
#                           model  \
# 0              Human and animal
# 1  Human and also murine models
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
#
#                                                 data  \
# 0                                             Review
# 1                                                NaN
# 2                                              Human
# 3  meta-analysis across 19 cohorts using 450k ill...
# 4  Simulation and application to complex traits f...
# 5                                                HRS
# 6  Several studies, including the Framingham coho...
#
#                                              methods  \
# 0                                                NaN
# 1                                                NaN
# 2  Different large-scale methylation studies usin...
# 3  2 models: primary análisis used continous bmi ...
# 4  Detect GxE based on the variance heterogeneity...
# 5  Uses a HLM whereby they estimate effects of ag...
# 6  Conditional quantile regression (CQR) to inves...
#
#                                          conclusions  \
# 0                                                NaN
# 1  -          The main exposures involved: fetal ...
# 2                                                NaN
# 3  They found evicence for a causal intrauterine ...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#                                             the_good  \
# 0  Good summary tables of studies carried out in ...
# 1                                                NaN
# 2  Also covers diet (methyl donnors) and epigenet...
# 3  Large sample size n=7523. Strong confounder co...
# 4  Interesting approach to GxE and GxG. The metho...
# 5                                                NaN
# 6               Interesting approach to GxE and GxG.
#
#                                          limitations  \
# 0  So far, a causal role of epigenetics in the de...
# 1  limited evidence for  a causal role for epigen...
# 2  In epigenetic studies it’s important to unders...
# 3  Effects sizes were very small, les tan a 0.15%...
# 4  The interaction effect estimates may depend to...
# 5  Pays little attention to selection due to surv...
# 6  European ancestry, how these results hold in d...
#
#                                              results  \
# 0                                                NaN
# 1                                                NaN
# 2  1) Evidence for DNA methylation sites that con...
# 3                                                NaN
# 4  Simulation results seem to show the method is ...
# 5                                                NaN
# 6  Significant positive associations (adjusting f...
#
#                                              context  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  GxE are challenging, E is not measured accurat...
# 5                                                NaN
# 6  The role of the individual and compound gene-e...
#
#                                                 next
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  What would be the implications of these result...
# 5                                           Anything
# 6  What would be the implications of these result...
